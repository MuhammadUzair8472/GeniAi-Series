# %%
from dotenv  import load_dotenv
load_dotenv()
# Out:
# True

# %%
# connect with google gemini api

from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")

# %%
res = llm.invoke("what is gennai ?")

# %%
res.content
# Out:
# [{'type': 'text',
#   'text': 'Depending on the context, **Gennai** can refer to a few different things, but the most common are a famous historical Japanese figure, an anime character, or a geographical name. \n\nHere are the most likely meanings:\n\n### 1. Hiraga Gennai (Historical Figure)\nIn Japanese history, **Hiraga Gennai** (1728–1799) was a famous *rangakusha* (a scholar of Western sciences), pharmacist, author, and inventor during the Edo period. \n* He is often called the "Leonardo da Vinci of Japan."\n* He is best known for creating the **Eereki**, a replica of an electrostatic generator (an early battery/generator device), and for his contributions to medicine, mining, and literature.\n\n### 2. Gennai (Digimon)\nIn the anime and media franchise *Digimon* (specifically *Digimon Adventure* and *Digimon Adventure 02*), **Gennai** is a mysterious, old-man-like digital entity who acts as a guide and mentor to the DigiDestined (the main human kids). \n* He helps them understand the Digital World and how to defeat the dark forces threatening it.\n* Later in the series, it is revealed there are multiple versions of Gennai, including a younger version.\n\n### 3. Geographical Locations in Japan\n"Gennai" can also refer to various place names or neighborhoods in Japan, though these are much less internationally famous.\n\n***\n\n*If you had a specific one of these in mind (or something else entirely), let me know and I can give you more details!*',
#   'extras': {'signature': 'El4KXAFpFH0TIm4t3mBXQBFWFzm5374mkfuR/OsBpS7jl2KkIkCdkvwY/e6m8WyYlstp7y/jVbX7NKKGwcG4UsmtQTvq5uBhktB8zSnZunqdflhf4frNfwErS+bG7dDm'}}]
