# %% [markdown]
# # 02 - Static Prompts in GenAI

# %%
from dotenv  import load_dotenv
load_dotenv()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
prompts=[
("system", "you are fimimlair from pakistan"),
("user","who is 804?")

]
res = llm.invoke(prompts)

res.content
# Out:
# [{'type': 'text',
#   'text': 'In Pakistan, **"804"** is not just a number anymore—it has become a powerful political and cultural symbol. \n\nIt refers to **Imran Khan**, the former Prime Minister of Pakistan and the founding chairman of the Pakistan Tehreek-e-Insaf (PTI) party. \n\nHere is why that number is everywhere in Pakistan:\n\n* **The Prisoner Number:** When Imran Khan was imprisoned in Attock Jail (and later Adiala Jail) following his conviction in August 2023, his official prison inmate/serial number was **804**.\n* **The "Ballot Box" Symbol:** During the February 2024 general elections, the Election Commission of Pakistan stripped PTI of its iconic election symbol (the cricket bat). Because PTI-backed candidates had to run as independents, they were assigned different electoral symbols. To help voters identify them, the party used "804" as a rallying cry, representing Imran Khan himself. Supporters often joked that while the state took away their "bat," they couldn\'t take away "804."\n* **A Symbol of Defiance:** Today, for millions of Pakistanis, 804 represents resistance against the establishment, a demand for the rule of law, and loyalty to Imran Khan. You will see it spray-painted on walls, trending on social media, and chanted at political rallies. \n\nSo, in short: In Pakistan today, asking "Who is 804?" is essentially asking about **Imran Khan**.',
#   'extras': {'signature': 'El4KXAFpFH0TULZbzjPz3BgROjwqEfXDV2EFTODGGxr9E8CPPce8be8yRuYk5b5C9ANoLzO7Kc6jP6W+qL+ZcplOvS9EEW6xKHtdR2Wk2wfFXHecpi8t8YCe++qQPIPd'}}]
